# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../../')
import do_mpc
import pandas as pd
import os

# %%
# %matplotlib notebook

# %%
file_list = os.listdir('./results/')[:36]


n_res = len(file_list)

# %%
len(file_list)
# Out:
# 36

# %%
res = []
for file_i in file_list:
    res.append(do_mpc.data.load_results('./results/'+file_i))

# %% [markdown]
# # Theta-phi Darstellung:

# %%
n_row = int(np.ceil(np.sqrt(n_res)))
n_col = int(np.ceil(n_res/n_row))

if True:
    fig, ax = plt.subplots(n_row, n_col, sharex=True, sharey=True, figsize=(8,8))
    for i, res_i in enumerate(res):
        ax[i//n_col, np.mod(i,n_col)].plot(res_i['simulator']['_x', 'phi'],res_i['simulator']['_x', 'theta'])
        ax[i//n_col, np.mod(i,n_col)].axis('off')
else:
    fig, ax = plt.subplots()
    for res_i in res:
        ax.plot(res_i['simulator']['_x', 'phi'],res_i['simulator']['_x', 'theta'])
        
    
fig.tight_layout(pad=0)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Windstärke Darstellung:

# %%
fig, ax = plt.subplots(n_row, n_col, sharex=True, sharey=True, figsize=(8,8))
for i, res_i in enumerate(res):
    ax[i//n_col, np.mod(i,n_col)].plot(res_i['simulator']['_time'],res_i['simulator']['_p', 'v_0'])
    
fig.tight_layout(pad=0.1)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # E_0 Darstellung:

# %%
if True:
    fig, ax = plt.subplots(n_row, n_col, sharex=True, sharey=True, figsize=(8,8))
    for i, res_i in enumerate(res):
        ax[i//n_col, np.mod(i,n_col)].plot(res_i['simulator']['_time'],res_i['simulator']['_p', 'E_0'])
else:
    fig, ax = plt.subplots(figsize=(5,5))
    for res_i in res:
        ax.plot(res_i['simulator']['_time'],res_i['simulator']['_p', 'E_0'])
fig.tight_layout(pad=0.1)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig, ax = plt.subplots(n_row, n_col, sharex=True, sharey=True, figsize=(6,6))
for i, res_i in enumerate(res):
    if 'mpc' in res_i.keys():
        ax[i//n_col, np.mod(i,n_col)].plot(res_i['mpc']['_time'],res_i['mpc']['success'])
    ax[i//n_col, np.mod(i,n_col)].axis('off')
fig.tight_layout(pad=0.1)
# Out:
# <div id='8eca155a-7daa-44df-b558-f496df48bddc'></div>
